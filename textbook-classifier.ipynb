# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from glob import glob

# %%
from datetime import datetime

# %%
from os import path

# %%
import pandas as pd

# %%
import json

# %%
raw_data = pd.read_csv("/Users/mariamendiburo/src/Textbook-Classifier/Raw data.xlsx - Small_Data.csv")

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b1946ac92492> in <module>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
raw_data
# Out:
#        state                     district   ncesid  id_online  \
# 0   Illinois                         CHSD      -99    22334.0
# 1   Illinois                Unit District      -99    55389.0
# 2   Illinois                         CHSD      -99    22334.0
# 3   Illinois                         CHSD      -99    22334.0
# 4   Illinois                   elementary      -99    14191.0
# 5   Illinois                Unit District      -99    55389.0
# 6   Illinois                         CHSD      -99    22334.0
# 7   Illinois                         CHSD      -99    22334.0
# 8   Illinois                Unit District      -99    55393.0
# 9   Illinois                Unit District      -99    55393.0
# 10  Illinois                   Elementary      -99    14281.0
# 11  Illinois                         CHSD      -99    22334.0
# 12  Illinois  Regional Alternative School      -99    17316.0
# 13  Illinois                         CHSD      -99    22334.0
# ...

# %%
math_books = pd.read_csv("/Users/mariamendiburo/src/Textbook-Classifier/TextbookFile_Math_020217.xlsx - Math_Texts_Small.csv")

# %%
math_books
# Out:
#      bookcode1415                          Publisher1415  \
# 0               0                      No Textbooks Used
# 1               1                         Addison Wesley
# 2               2                         Addison Wesley
# 3               3                         Addison Wesley
# 4               4                         Addison Wesley
# 5               5                         Addison Wesley
# 6               6                         Addison Wesley
# 7               7                         Addison Wesley
# 8               8                         Addison Wesley
# 9               9                         Addison Wesley
# 10             10                         Addison Wesley
# 11             11                             Agile Mind
# 12             12                             Agile Mind
# 13             13                                  ALEKS
# 14             14                                  ALEKS
# ...

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
process.extractOne('calculus', math_books['ActualTitle1415'].as_matrix, 60)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-9ce9bbd20e74> in <module>()
# ----> 1 process.extractOne('calculus', math_books['ActualTitle1415'].as_matrix, 60)
#
# /Users/mariamendiburo/anaconda/lib/python2.7/site-packages/fuzzywuzzy/process.pyc in extractOne(query, choices, processor, scorer, score_cutoff)
#     228     best_list = extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     229     try:
# --> 230         return max(best_list, key=lambda i: i[1])
#     231     except ValueError:
#     232         return None
#
# /Users/mariamendiburo/anaconda/lib/python2.7/site-packages/fuzzywuzzy/process.pyc in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     100
#     101     # Run the processor on the input query.
# --> 102     processed_query = processor(query)
#     103
# ...

# %%
blah = math_books['ActualTitle1415'].as_matrix

# %%
blah.as_matrix
# Out:
# <bound method Series.as_matrix of 0                                      No Textbooks Used
# 1                                               Calculus
# 2                          Calculus and its Applications
# 3                            Calculus: A Complete Course
# 4                                        College Algebra
# 5      Elementary and Intermediate Algebra Concepts a...
# 6                               Essentials of Statistics
# 7                    Foundations of Algebra and Geometry
# 8                                   Intermediate Algebra
# 9                                       Math Makes Sense
# 10                                          Trigonometry
# 11                     Common Core Algebra 1 Mathematics
# 12                 Common Core Middle School Mathematics
# 13                                            Algebra 1A
# 14                                            Algebra 1B
# 15                                 California Algebra 1A
# ...

# %%
math_books.as_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-2f8bbf6098cb> in <module>()
# ----> 1 math_books.as_dict
#
# /Users/mariamendiburo/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2742             if name in self._info_axis:
#    2743                 return self[name]
# -> 2744             return object.__getattribute__(self, name)
#    2745
#    2746     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'as_dict'

# %%
math_books['ActualTitle1415'].map(lambda x: process.extractOne('calculus', [x])[1] > 60)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 83     False
# 84     False
# 85     False
# 86     False
# 87     False
# 88     False
# 89     False
# 90     False
# 91     False
# 92     False
# 93     False
# 94     False
# 95     False
# 96     False
# 97     False
# 98     False
# 99     False
# 100    False
# 101    False
# 102     True
# 103    False
# 104    False
# 105    False
# 106     True
# 107    False
# 108    False
# 109    False
# 110     True
# 111    False
# 112    False
# Name: ActualTitle1415, dtype: bool

# %%
process.extractOne('calculus', ['calculus'])
# Out:
# ('calculus', 100)

# %%
math_books.index[3]
# Out:
# 3
